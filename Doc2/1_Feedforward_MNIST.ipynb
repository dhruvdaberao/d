# %%
# Practical 1: Feedforward Neural Network for MNIST Dataset

# Step 1: Import Libraries
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt

# %%
# Step 2: Load and Preprocess Data
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train / 255.0
x_test = x_test / 255.0
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 17s 1us/step

# %%
# Step 3: Define Model Architecture
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])
# Out:
# C:\Users\dhruv\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Step 4: Compile the Model
model.compile(optimizer='SGD',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Step 5: Train the Model
history = model.fit(x_train, y_train, epochs=11, validation_data=(x_test, y_test))
# Out:
# Epoch 1/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8397 - loss: 0.6075 - val_accuracy: 0.9089 - val_loss: 0.3158
# Epoch 2/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9171 - loss: 0.2918 - val_accuracy: 0.9277 - val_loss: 0.2506
# Epoch 3/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9301 - loss: 0.2404 - val_accuracy: 0.9385 - val_loss: 0.2168
# Epoch 4/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9403 - loss: 0.2068 - val_accuracy: 0.9464 - val_loss: 0.1887
# Epoch 5/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9479 - loss: 0.1814 - val_accuracy: 0.9487 - val_loss: 0.1742
# Epoch 6/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9532 - loss: 0.1623 - val_accuracy: 0.9540 - val_loss: 0.1556
# Epoch 7/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9572 - loss: 0.1457 - val_accuracy: 0.9582 - val_loss: 0.1417
# Epoch 8/11
# ...

# %%
# Step 6: Evaluate the Model
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print("\nTest Accuracy:", test_acc)
# Out:
# 313/313 - 1s - 4ms/step - accuracy: 0.9665 - loss: 0.1112
#
# Test Accuracy: 0.9664999842643738

# %%
# Step 7: Plot Loss and Accuracy Graphs
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
# ------------------------------------------------------------
# EXPLANATION OF EACH STEP
# ------------------------------------------------------------
# Step 1: Import Libraries
# - TensorFlow/Keras for model building, Matplotlib for graph visualization.

# Step 2: Load and Preprocess Data
# - MNIST contains 70,000 images of handwritten digits (0–9).
# - Normalized (0–1) for faster and stable training.

# Step 3: Define Model Architecture
# - Flatten: converts 28x28 to a 1D array (784).
# - Dense layers: fully connected layers with ReLU for non-linearity.
# - Output layer uses Softmax for 10-class classification.

# Step 4: Compile the Model
# - Optimizer: SGD (Stochastic Gradient Descent)
# - Loss: Sparse categorical crossentropy (for integer labels)
# - Metric: Accuracy

# Step 5: Train the Model
# - Runs for 11 epochs.
# - Validation data checks unseen performance per epoch.

# Step 6: Evaluate the Model
# - Evaluates accuracy on test data (expected 97–99%).

# Step 7: Plot Graphs
# - Training vs Validation Loss & Accuracy.
# - Used to check overfitting (when training accuracy >> validation).

# ------------------------------------------------------------
# VIVA QUESTIONS
# ------------------------------------------------------------
# Q1. What is MNIST dataset?
#     -> Handwritten digits (0–9), each image is 28x28 pixels.
# Q2. What is a Feedforward Neural Network?
#     -> Data flows only from input to output layers (no loops).
# Q3. Why normalize data?
#     -> To scale pixel values between 0–1 for faster training.
# Q4. Why use ReLU activation?
#     -> Adds non-linearity and prevents vanishing gradients.
# Q5. What does Softmax do?
#     -> Converts outputs into probability distribution.
# Q6. What is SGD?
#     -> Optimizer that updates weights gradually using gradient descent.
# Q7. What is an epoch?
#     -> One full pass through the training data.
# Q8. What accuracy do we expect?
#     -> Around 97–99%.
# Q9. What does model.evaluate() return?
#     -> Test loss and accuracy on unseen data.
# Q10. What indicates overfitting?
#     -> High training accuracy but low validation accuracy.
